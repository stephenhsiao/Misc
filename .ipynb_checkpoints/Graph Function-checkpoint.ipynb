# %%
#General imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def graph(x_range):  
    # set the x ranges
    x = np.array(x_range) 
    
    # set the function
    y = np.power(1.0+1.0/x,x)
    
    # configurations
    fig = plt.figure(figsize=(10, 8), dpi=100)
    plt.plot(x, y)
    plt.title('LineChart')
    plt.xlabel('n')
    plt.ylabel('f(x)')
    plt.grid(True)
    plt.show()

# %%
# plot the function
graph(range(1, 200))
