# %%
# General imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import csv
import seaborn as sns

# %%
def graph(x_range):  
    # set the x ranges
    x = np.array(x_range) 
    
    # set the function
    # y = np.power(1.0+1.0/x,x)
    # Logistic function
    y = 1 / (1 + np.exp(-x))
    
    # configurations
    fig = plt.figure(figsize=(10, 8), dpi=100)
    plt.plot(x, y)
    plt.title('LineChart')
    plt.xlabel('n')
    plt.ylabel('f(x)')
    plt.grid(True)
    plt.show()

# %%
# plot the function
graph(range(-20, 20))

# %%
# Distribution plotter
# Give the title of the chart and data set
def distribution_plotter(title, data):
    sns.set(rc={"figure.figsize": (10, 7)})
    sns.set_style("white")
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    dist.set_title(title, fontsize=16)

# %%
# Normal Distrubution
norm = np.random.normal(-1, 1, size=1000)
distribution_plotter("test", norm)

# %%
# Uniform Distribution
uni = np.random.uniform(-1, 1, size=1000)
distribution_plotter("test", uni)

# %%
# Plot both together
distribution_plotter("test", uni)
distribution_plotter("test", norm)
